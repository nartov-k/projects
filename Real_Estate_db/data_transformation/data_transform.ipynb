# %%
import pandas as pd 
import numpy as np

# %% [markdown]
# # metro median price df

# %%
df1 = pd.read_csv('./metro_median_price.csv')

# %%
df1
# Out:
#      RegionID  SizeRank       RegionName RegionType StateName  2018-03-31  \
# 0      102001         0    United States    country       NaN    263267.0
# 1      394913         1     New York, NY        msa        NY    503000.0
# 2      753899         2  Los Angeles, CA        msa        CA    721333.0
# 3      394463         3      Chicago, IL        msa        IL    284600.0
# 4      394514         4       Dallas, TX        msa        TX    322997.0
# ..        ...       ...              ...        ...       ...         ...
# 923    753929       935       Zapata, TX        msa        TX         NaN
# 924    394743       936    Ketchikan, AK        msa        AK    284500.0
# 925    753874       937        Craig, CO        msa        CO    192833.0
# 926    395188       938       Vernon, TX        msa        TX         NaN
# 927    394767       939       Lamesa, TX        msa        TX     96800.0
#
#      2018-04-30  2018-05-31  2018-06-30  2018-07-31  ...  2023-01-31  \
# ...

# %%
df1.columns = df1.columns.str.replace('-','_')

# %%
df1.columns[5:]
# Out:
# Index(['2018_03_31', '2018_04_30', '2018_05_31', '2018_06_30', '2018_07_31',
#        '2018_08_31', '2018_09_30', '2018_10_31', '2018_11_30', '2018_12_31',
#        '2019_01_31', '2019_02_28', '2019_03_31', '2019_04_30', '2019_05_31',
#        '2019_06_30', '2019_07_31', '2019_08_31', '2019_09_30', '2019_10_31',
#        '2019_11_30', '2019_12_31', '2020_01_31', '2020_02_29', '2020_03_31',
#        '2020_04_30', '2020_05_31', '2020_06_30', '2020_07_31', '2020_08_31',
#        '2020_09_30', '2020_10_31', '2020_11_30', '2020_12_31', '2021_01_31',
#        '2021_02_28', '2021_03_31', '2021_04_30', '2021_05_31', '2021_06_30',
#        '2021_07_31', '2021_08_31', '2021_09_30', '2021_10_31', '2021_11_30',
#        '2021_12_31', '2022_01_31', '2022_02_28', '2022_03_31', '2022_04_30',
#        '2022_05_31', '2022_06_30', '2022_07_31', '2022_08_31', '2022_09_30',
#        '2022_10_31', '2022_11_30', '2022_12_31', '2023_01_31', '2023_02_28',
# ...

# %%
df1.columns = ['date_'+str(col) 
                if col in df1.columns[5:] 
                else col for col in df1.columns]

# %%
df1
# Out:
#      RegionID  SizeRank       RegionName RegionType StateName  \
# 0      102001         0    United States    country       NaN
# 1      394913         1     New York, NY        msa        NY
# 2      753899         2  Los Angeles, CA        msa        CA
# 3      394463         3      Chicago, IL        msa        IL
# 4      394514         4       Dallas, TX        msa        TX
# ..        ...       ...              ...        ...       ...
# 923    753929       935       Zapata, TX        msa        TX
# 924    394743       936    Ketchikan, AK        msa        AK
# 925    753874       937        Craig, CO        msa        CO
# 926    395188       938       Vernon, TX        msa        TX
# 927    394767       939       Lamesa, TX        msa        TX
#
#      date_2018_03_31  date_2018_04_30  date_2018_05_31  date_2018_06_30  \
# 0           263267.0         271267.0         276633.0         280000.0
# 1           503000.0         513000.0         521300.0         526300.0
# ...

# %%
columns = [] 
for i in df1.columns:
    print(i+',')
    columns.append(i)
# Out:
# RegionID,
# SizeRank,
# RegionName,
# RegionType,
# StateName,
# date_2018_03_31,
# date_2018_04_30,
# date_2018_05_31,
# date_2018_06_30,
# date_2018_07_31,
# date_2018_08_31,
# date_2018_09_30,
# date_2018_10_31,
# date_2018_11_30,
# date_2018_12_31,
# date_2019_01_31,
# date_2019_02_28,
# date_2019_03_31,
# date_2019_04_30,
# date_2019_05_31,
# date_2019_06_30,
# date_2019_07_31,
# date_2019_08_31,
# date_2019_09_30,
# date_2019_10_31,
# date_2019_11_30,
# date_2019_12_31,
# date_2020_01_31,
# date_2020_02_29,
# date_2020_03_31,
# date_2020_04_30,
# date_2020_05_31,
# date_2020_06_30,
# date_2020_07_31,
# date_2020_08_31,
# date_2020_09_30,
# date_2020_10_31,
# date_2020_11_30,
# date_2020_12_31,
# date_2021_01_31,
# date_2021_02_28,
# date_2021_03_31,
# date_2021_04_30,
# date_2021_05_31,
# date_2021_06_30,
# date_2021_07_31,
# date_2021_08_31,
# date_2021_09_30,
# date_2021_10_31,
# date_2021_11_30,
# date_2021_12_31,
# date_2022_01_31,
# date_2022_02_28,
# date_2022_03_31,
# ...

# %%
columns
# Out:
# ['RegionID',
#  'SizeRank',
#  'RegionName',
#  'RegionType',
#  'StateName',
#  'date_2018_03_31',
#  'date_2018_04_30',
#  'date_2018_05_31',
#  'date_2018_06_30',
#  'date_2018_07_31',
#  'date_2018_08_31',
#  'date_2018_09_30',
#  'date_2018_10_31',
#  'date_2018_11_30',
#  'date_2018_12_31',
#  'date_2019_01_31',
#  'date_2019_02_28',
#  'date_2019_03_31',
#  'date_2019_04_30',
#  'date_2019_05_31',
#  'date_2019_06_30',
#  'date_2019_07_31',
#  'date_2019_08_31',
#  'date_2019_09_30',
#  'date_2019_10_31',
#  'date_2019_11_30',
#  'date_2019_12_31',
#  'date_2020_01_31',
#  'date_2020_02_29',
#  'date_2020_03_31',
#  'date_2020_04_30',
#  'date_2020_05_31',
#  'date_2020_06_30',
#  'date_2020_07_31',
#  'date_2020_08_31',
#  'date_2020_09_30',
#  'date_2020_10_31',
#  'date_2020_11_30',
#  'date_2020_12_31',
#  'date_2021_01_31',
#  'date_2021_02_28',
#  'date_2021_03_31',
#  'date_2021_04_30',
#  'date_2021_05_31',
#  'date_2021_06_30',
#  'date_2021_07_31',
# ...

# %%
# df1 = df1.add_prefix('date_')

# %%
df1.to_csv('./metro_median_price_tranformed.csv')

# %% [markdown]
# # metro median sale df

# %%
df2 = pd.read_csv('./metro_median_sale.csv')

# %%
df2
# Out:
#      RegionID  SizeRank       RegionName RegionType StateName  2008-04-30  \
# 0      102001         0    United States    country       NaN    179808.5
# 1      394913         1     New York, NY        msa        NY    392500.0
# 2      753899         2  Los Angeles, CA        msa        CA    460000.0
# 3      394463         3      Chicago, IL        msa        IL    229000.0
# 4      394514         4       Dallas, TX        msa        TX    146000.0
# ..        ...       ...              ...        ...       ...         ...
# 781    786257       914     Fairmont, MN        msa        MN         NaN
# 782    394805       916   Los Alamos, NM        msa        NM         NaN
# 783    395112       922  Spirit Lake, IA        msa        IA         NaN
# 784    395111       928      Spencer, IA        msa        IA         NaN
# 785    753874       937        Craig, CO        msa        CO         NaN
#
#      2008-05-31  2008-06-30  2008-07-31  2008-08-31  ...  2022-12-31  \
# ...

# %%
df2.columns = df2.columns.str.replace('-','_')

# %%
df2.columns[5:]
# Out:
# Index(['2008_04_30', '2008_05_31', '2008_06_30', '2008_07_31', '2008_08_31',
#        '2008_09_30', '2008_10_31', '2008_11_30', '2008_12_31', '2009_01_31',
#        ...
#        '2022_12_31', '2023_01_31', '2023_02_28', '2023_03_31', '2023_04_30',
#        '2023_05_31', '2023_06_30', '2023_07_31', '2023_08_31', '2023_09_30'],
#       dtype='object', length=186)

# %%
df2.columns = ['date_'+str(col) 
                if col in df2.columns[5:] 
                else col for col in df2.columns]

# %%
df2
# Out:
#      RegionID  SizeRank       RegionName RegionType StateName  \
# 0      102001         0    United States    country       NaN
# 1      394913         1     New York, NY        msa        NY
# 2      753899         2  Los Angeles, CA        msa        CA
# 3      394463         3      Chicago, IL        msa        IL
# 4      394514         4       Dallas, TX        msa        TX
# ..        ...       ...              ...        ...       ...
# 781    786257       914     Fairmont, MN        msa        MN
# 782    394805       916   Los Alamos, NM        msa        NM
# 783    395112       922  Spirit Lake, IA        msa        IA
# 784    395111       928      Spencer, IA        msa        IA
# 785    753874       937        Craig, CO        msa        CO
#
#      date_2008_04_30  date_2008_05_31  date_2008_06_30  date_2008_07_31  \
# 0           179808.5         180500.0         183700.0         185700.0
# 1           392500.0         395000.0         397500.0         405000.0
# ...

# %%
columns[:-1]
# Out:
# ['RegionID',
#  'SizeRank',
#  'RegionName',
#  'RegionType',
#  'StateName',
#  'date_2018_03_31',
#  'date_2018_04_30',
#  'date_2018_05_31',
#  'date_2018_06_30',
#  'date_2018_07_31',
#  'date_2018_08_31',
#  'date_2018_09_30',
#  'date_2018_10_31',
#  'date_2018_11_30',
#  'date_2018_12_31',
#  'date_2019_01_31',
#  'date_2019_02_28',
#  'date_2019_03_31',
#  'date_2019_04_30',
#  'date_2019_05_31',
#  'date_2019_06_30',
#  'date_2019_07_31',
#  'date_2019_08_31',
#  'date_2019_09_30',
#  'date_2019_10_31',
#  'date_2019_11_30',
#  'date_2019_12_31',
#  'date_2020_01_31',
#  'date_2020_02_29',
#  'date_2020_03_31',
#  'date_2020_04_30',
#  'date_2020_05_31',
#  'date_2020_06_30',
#  'date_2020_07_31',
#  'date_2020_08_31',
#  'date_2020_09_30',
#  'date_2020_10_31',
#  'date_2020_11_30',
#  'date_2020_12_31',
#  'date_2021_01_31',
#  'date_2021_02_28',
#  'date_2021_03_31',
#  'date_2021_04_30',
#  'date_2021_05_31',
#  'date_2021_06_30',
#  'date_2021_07_31',
# ...

# %%
df2 = df2[columns[:-1]]

# %%
df2
# Out:
#      RegionID  SizeRank       RegionName RegionType StateName  \
# 0      102001         0    United States    country       NaN
# 1      394913         1     New York, NY        msa        NY
# 2      753899         2  Los Angeles, CA        msa        CA
# 3      394463         3      Chicago, IL        msa        IL
# 4      394514         4       Dallas, TX        msa        TX
# ..        ...       ...              ...        ...       ...
# 781    786257       914     Fairmont, MN        msa        MN
# 782    394805       916   Los Alamos, NM        msa        NM
# 783    395112       922  Spirit Lake, IA        msa        IA
# 784    395111       928      Spencer, IA        msa        IA
# 785    753874       937        Craig, CO        msa        CO
#
#      date_2018_03_31  date_2018_04_30  date_2018_05_31  date_2018_06_30  \
# 0           222000.0         226950.0         230700.0         236250.0
# 1           374500.0         380000.0         385500.0         400500.0
# ...

# %%
df2.to_csv('./metro_median_sale_transformed.csv')

# %% [markdown]
# # metro listing cut df

# %%
df3 = pd.read_csv('./metro_share_listings_price_cut.csv')

# %%
df3
# Out:
#      RegionID  SizeRank       RegionName RegionType StateName  2018-03-31  \
# 0      102001         0    United States    country       NaN    0.146670
# 1      394913         1     New York, NY        msa        NY    0.120111
# 2      753899         2  Los Angeles, CA        msa        CA    0.147420
# 3      394463         3      Chicago, IL        msa        IL    0.189776
# 4      394514         4       Dallas, TX        msa        TX    0.166377
# ..        ...       ...              ...        ...       ...         ...
# 923    753929       935       Zapata, TX        msa        TX         NaN
# 924    394743       936    Ketchikan, AK        msa        AK    0.095288
# 925    753874       937        Craig, CO        msa        CO    0.061116
# 926    395188       938       Vernon, TX        msa        TX         NaN
# 927    394767       939       Lamesa, TX        msa        TX    0.101107
#
#      2018-04-30  2018-05-31  2018-06-30  2018-07-31  ...  2023-01-31  \
# ...

# %%
df3.columns = df3.columns.str.replace('-','_')

# %%
df3.columns[5:]
# Out:
# Index(['2018_03_31', '2018_04_30', '2018_05_31', '2018_06_30', '2018_07_31',
#        '2018_08_31', '2018_09_30', '2018_10_31', '2018_11_30', '2018_12_31',
#        '2019_01_31', '2019_02_28', '2019_03_31', '2019_04_30', '2019_05_31',
#        '2019_06_30', '2019_07_31', '2019_08_31', '2019_09_30', '2019_10_31',
#        '2019_11_30', '2019_12_31', '2020_01_31', '2020_02_29', '2020_03_31',
#        '2020_04_30', '2020_05_31', '2020_06_30', '2020_07_31', '2020_08_31',
#        '2020_09_30', '2020_10_31', '2020_11_30', '2020_12_31', '2021_01_31',
#        '2021_02_28', '2021_03_31', '2021_04_30', '2021_05_31', '2021_06_30',
#        '2021_07_31', '2021_08_31', '2021_09_30', '2021_10_31', '2021_11_30',
#        '2021_12_31', '2022_01_31', '2022_02_28', '2022_03_31', '2022_04_30',
#        '2022_05_31', '2022_06_30', '2022_07_31', '2022_08_31', '2022_09_30',
#        '2022_10_31', '2022_11_30', '2022_12_31', '2023_01_31', '2023_02_28',
# ...

# %%
df3.columns = ['date_'+str(col) 
                if col in df3.columns[5:] 
                else col for col in df3.columns]

# %%
df3
# Out:
#      RegionID  SizeRank       RegionName RegionType StateName  \
# 0      102001         0    United States    country       NaN
# 1      394913         1     New York, NY        msa        NY
# 2      753899         2  Los Angeles, CA        msa        CA
# 3      394463         3      Chicago, IL        msa        IL
# 4      394514         4       Dallas, TX        msa        TX
# ..        ...       ...              ...        ...       ...
# 923    753929       935       Zapata, TX        msa        TX
# 924    394743       936    Ketchikan, AK        msa        AK
# 925    753874       937        Craig, CO        msa        CO
# 926    395188       938       Vernon, TX        msa        TX
# 927    394767       939       Lamesa, TX        msa        TX
#
#      date_2018_03_31  date_2018_04_30  date_2018_05_31  date_2018_06_30  \
# 0           0.146670         0.151549         0.166976         0.180623
# 1           0.120111         0.128204         0.148470         0.168090
# ...

# %%
df3.to_csv('./metro_share_listings_price_cut_transformed.csv')

# %% [markdown]
# # metro zori df

# %%
df4 = pd.read_csv('./metro_zori.csv')

# %%
df4
# Out:
#      RegionID  SizeRank       RegionName RegionType StateName   2015-01-31  \
# 0      102001         0    United States    country       NaN  1258.829246
# 1      394913         1     New York, NY        msa        NY  2369.677360
# 2      753899         2  Los Angeles, CA        msa        CA  1874.902698
# 3      394463         3      Chicago, IL        msa        IL  1399.490422
# 4      394514         4       Dallas, TX        msa        TX  1125.269027
# ..        ...       ...              ...        ...       ...          ...
# 595    394687       875   Hood River, OR        msa        OR          NaN
# 596    394868       878     Mitchell, SD        msa        SD          NaN
# 597    395198       882     Wahpeton, ND        msa        ND          NaN
# 598    394718       892    Jamestown, ND        msa        ND          NaN
# 599    394996       915     Portales, NM        msa        NM          NaN
#
# ...

# %%
df4.columns = df4.columns.str.replace('-','_')

# %%
df4.columns[5:]
# Out:
# Index(['2015_01_31', '2015_02_28', '2015_03_31', '2015_04_30', '2015_05_31',
#        '2015_06_30', '2015_07_31', '2015_08_31', '2015_09_30', '2015_10_31',
#        ...
#        '2023_01_31', '2023_02_28', '2023_03_31', '2023_04_30', '2023_05_31',
#        '2023_06_30', '2023_07_31', '2023_08_31', '2023_09_30', '2023_10_31'],
#       dtype='object', length=106)

# %%
df4.columns = ['date_'+str(col) 
                if col in df4.columns[5:] 
                else col for col in df4.columns]

# %%
df4 = df4[columns]

# %%
df4
# Out:
#      RegionID  SizeRank       RegionName RegionType StateName  \
# 0      102001         0    United States    country       NaN
# 1      394913         1     New York, NY        msa        NY
# 2      753899         2  Los Angeles, CA        msa        CA
# 3      394463         3      Chicago, IL        msa        IL
# 4      394514         4       Dallas, TX        msa        TX
# ..        ...       ...              ...        ...       ...
# 595    394687       875   Hood River, OR        msa        OR
# 596    394868       878     Mitchell, SD        msa        SD
# 597    395198       882     Wahpeton, ND        msa        ND
# 598    394718       892    Jamestown, ND        msa        ND
# 599    394996       915     Portales, NM        msa        NM
#
#      date_2018_03_31  date_2018_04_30  date_2018_05_31  date_2018_06_30  \
# 0        1439.118278      1449.259355      1458.047410      1465.862856
# 1        2548.978635      2569.804086      2588.396962      2606.786619
# ...

# %%
df4.to_csv('./metro_zori_transformed.csv')
